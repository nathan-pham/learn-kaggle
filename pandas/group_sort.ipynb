# %% [markdown]
# # Group and Sort

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Import Dataset

# %%
dataset = pd.read_csv("./datasets/chickweight.csv")

# %%
dataset.head()
# Out:
#    weight  Time  Chick  Diet
# 0      42     0      1     1
# 1      51     2      1     1
# 2      59     4      1     1
# 3      64     6      1     1
# 4      76     8      1     1

# %% [markdown]
# ## Groupwise Analysis

# %%
dataset.count()
# Out:
# weight    578
# Time      578
# Chick     578
# Diet      578
# dtype: int64

# %%
grouped_dataset = dataset.groupby(["Diet", "Chick"]).weight.agg([min, max])
grouped_dataset.head()
# Out:
#             min  max
# Diet Chick
# 1    1       42  205
#      2       40  215
#      3       39  202
#      4       42  160
#      5       41  223

# %% [markdown]
# Reset the multiple indexes created with `groupby`

# %%
grouped_dataset = grouped_dataset.reset_index()
grouped_dataset.head()
# Out:
#    index  Diet  Chick  min  max
# 0      0     1      1   42  205
# 1      1     1      2   40  215
# 2      2     1      3   39  202
# 3      3     1      4   42  160
# 4      4     1      5   41  223

# %% [markdown]
# ## Sorting

# %%
grouped_dataset.sort_values(by="min").head()
# Out:
#     Diet  Chick  min  max
# 17     1     18   35   39
# 35     3     36   39  227
# 26     2     27   39  192
# 2      1      3   39  202
# 47     4     48   39  322

# %%
grouped_dataset.sort_values(by=["Diet", "max"], ascending=False).head()
# Out:
#     index  Diet  Chick  min  max
# 47     47     4     48   39  322
# 41     41     4     42   42  281
# 49     49     4     50   41  264
# 45     45     4     46   40  238
# 48     48     4     49   40  237

# %% [markdown]
# Return everything to its default values with `dataset.sort_index()`

# %%
grouped_dataset.sort_index().head()
# Out:
#    index  Diet  Chick  min  max
# 0      0     1      1   42  205
# 1      1     1      2   40  215
# 2      2     1      3   39  202
# 3      3     1      4   42  160
# 4      4     1      5   41  223
